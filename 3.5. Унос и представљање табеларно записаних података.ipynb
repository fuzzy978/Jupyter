# %% [markdown]
# # Унос и представљање табеларно записаних података

# %% [markdown]
# ## Задатак 1
# Табела садржи податке са именима ученика различитог пола, узраста и успеха на крају претходне школске године.
# ![image.png](attachment:image.png)
# 1. Табелу унети у низ под називом podaci.
# 2. Израчунати просечну старост ученика.
# 3. Израчунати просечну оцену одељења заокружен на две децимале.

# %% [markdown]
# ## Задатак 2: Библиотека pandas
# 1. Податке о ученицима приказати табеларно.

# %% [markdown]
# ## Задатак 3
# 1. Направи табелу у којој ћеш у:
#     - првој колони навести имена својих другарица и другова из одељења (најмање 10),
#     - друга колона нека садржи просек у 6.
#     - трећа колона просек у 7.
#     - и четврта колона (прижељкивани) просек у 8. разреду.
